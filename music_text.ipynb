# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshimehra072/cpp/blob/main/music_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/spotify_millsongdata.csv')

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
print(df)
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df=df.sample(5000).drop('link',axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#              artist                        song  \
# 0             Verve     This Could Be My Moment
# 1      Donna Summer                     My Life
# 2           Tiffany                    Our Love
# 3      Van Morrison                Country Fair
# 4  Barbra Streisand        Children Will Listen
# 5  Gordon Lightfoot                Redwood Hill
# 6        Steely Dan  Throw Back The Little Ones
# 7         Green Day             Know Your Enemy
# 8         Tom Waits              Blue Valentine
# 9  Yngwie Malmsteen                Bedroom Eyes
#
#                                                 text
# 0  I'm the only man who ever really thought that ...
# 1  When I was young  \r\nI used to dream of going...
# 2  [Chorus]  \r\nOur love I could never live with...
# 3  We stood and watched the river flow  \r\nWe we...
# 4  How do you say to your child in the night  \r\...
# 5  I climbed the Redwood Hill  \r\n'Twas on a rai...
# 6  Lost in the Barrio I walk like an Injun  \r\nS...
# ...

# %%
df['text'][0]
# Out:
# "I'm the only man who ever really thought that I had qualified  \r\nFrom the corners of your mind you would care for another guy,  \r\n  \r\nNow I'm lookin at you straight in the eye,  \r\nI know it feels good and I know you should try me  \r\n  \r\nBut every chance you get you just hesitate,  \r\nIs there something in my look that you really hate,  \r\n  \r\nOpen me up I feel real glad,  \r\nYou can take all I have,  \r\nMaybe maybe dont you think its time  \r\n  \r\nThis could be my moment, somethin' more than weather  \r\nDon't you wanna try it (maybe, maybe)  \r\nThis could be my moment, somethin more than weather  \r\nDon't you wanna try it  \r\n  \r\nI'll open up my mind I swear I'd let you in  \r\nThere's nothin that you couldent beg steal or have  \r\nI'm lookin at you straight in the eye  \r\nI know it feels good and I know ya'll high  \r\nMaybe, maybe dont you think its time  \r\n  \r\nThis could be my moment, somethin' more than weather  \r\nDon't you wanna try it (maybe, 
# ...

# %%
# df=df.sample(5000)
# df = df.sample(5000, replace=True)

# %%
df.shape
# Out:
# (5000, 3)

# %%
#Text cleaning/Text Processing

# df['text'].str.lower().replace(r'^a-ZA-Z0-9','')
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex=True)

# %%
df.tail(5)
# Out:
#              artist                               song  \
# 4995     Perry Como            Accentuate The Positive
# 4996        Rainbow                   Street Of Dreams
# 4997      Marillion  You've Got To Hide Your Love Away
# 4998          Usher                      Love Was Here
# 4999  Ozzy Osbourne                             Denial
#
#                                                    text
# 4995  (ac-cent-thu-ate the positive,  \r e-lim-inate...
# 4996  i heard the sound of voices in the night  \r s...
# 4997  here i stand head in hand  \r turn my face to ...
# 4998  baby tonight  \r if you come home  \r i'll mak...
# 4999  you are my only daughter, i guess i made you t...

# %%
df['text']
# Out:
# 0       i'm the only man who ever really thought that ...
# 1       when i was young  \r i used to dream of going ...
# 2       [chorus]  \r our love i could never live witho...
# 3       we stood and watched the river flow  \r we wer...
# 4       how do you say to your child in the night  \r ...
#                               ...
# 4995    (ac-cent-thu-ate the positive,  \r e-lim-inate...
# 4996    i heard the sound of voices in the night  \r s...
# 4997    here i stand head in hand  \r turn my face to ...
# 4998    baby tonight  \r if you come home  \r i'll mak...
# 4999    you are my only daughter, i guess i made you t...
# Name: text, Length: 5000, dtype: object

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
# from tkinter.constants import W
def token(txt):
 token = nltk.word_tokenize(txt)
 a=[stemmer.stem(W) for W in token]
 return " ".join(a)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
'you are beauti , beauti'
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x : token(x))
# Out:
# 0       i 'm the onli man who ever realli thought that...
# 1       when i wa young i use to dream of go far have ...
# 2       [ choru ] our love i could never live without ...
# 3       we stood and watch the river flow we were too ...
# 4       how do you say to your child in the night noth...
#                               ...
# 4995    ( ac-cent-thu- the posit , e-lim-in the neg , ...
# 4996    i heard the sound of voic in the night spellbo...
# 4997    here i stand head in hand turn my face to the ...
# 4998    babi tonight if you come home i 'll make it ri...
# 4999    you are my onli daughter , i guess i made you ...
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Create an instance of TfidfVectorizer
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# Now you can use `tfidf` for text vectorization or feature extraction

# %%
matrix=tfidf.fit_transform(df['text'])

# %%
similer = cosine_similarity(matrix)

# %%
similer[5]
# Out:
# array([0.01459193, 0.00561643, 0.02638157, ..., 0.01863846, 0.01050058,
#        0.01309575])

# %%
df[df['song']=='Street Of Dreams'].index[0]
# Out:
# 4996

# %%
# def recommender(song_name):
#   idx = df[df['song']==song_name].index[0]
#   distance = sorted(list(enumerate(similer[idx])), reverse=True, key = lambda x:x[1])
#   song = []
#   for s_id in distance[5:15]:
# #   s_id= "\n".join(distance[1:15])
# # print(s_id)

#     song.append(df.iloc[s_id[0]].song)
#     return song

# %%
def recommender(song_name):
    idx = df[df['song']==song_name].index[0]
    distance = sorted(list(enumerate(similer[idx])), reverse=True, key=lambda x:x[1])
    songs = []
    for s_id in distance[1:25]:
        songs.append(df.iloc[s_id[0]].song)
    return songs

# %%
recommender('Street Of Dreams')
# Out:
# ["Don't Go Down That Street",
#  'Basin Street Blues',
#  'Street Mission',
#  'Just A Dream',
#  'Dreams',
#  'A Million Dreams Ago',
#  'Running Wild',
#  'Street Life',
#  'Could It Be You?',
#  'On The Sunny Side Of The Street',
#  'Our House',
#  'Bulbs',
#  "Let's Make A Memory",
#  'Moon Over Bourbon Street',
#  'In My Dreams',
#  'Always Have, Always Will',
#  'I Want You With Me',
#  'Hello, Young Lovers',
#  "Heaven's Falling",
#  'There Is A Time',
#  'Kicks On The Street',
#  'Running With The Night',
#  'Street Player',
#  'Dreams Are More Precious']

# %%
import pickle

# %%
pickle.dump(similer, open("similarity","wb"))

# %%
pickle.dump(df, open("df", "wb"))
